# %% [markdown]
# # Neccessary Import Statements

# %%
# data manipulation and storage
import numpy as np
import pandas as pd
# file and directory navigation
import os
# text parsing, we do a lot of it here.
import re

# %% [markdown]
# # See What Structure The Data Is In

# %% [markdown]
# ### Get a List of All of the Files

# %% [markdown]
# Note that this data can be found at [this link](https://www.kaggle.com/crawford/20-newsgroups/data?select=list.csv).

# %%
# navigate to directory in which the files are stored
data_dir = '/Users/sebgo/Documents/Hindsight/hierarchical_text_classification/20_newsgroup/data/raw_data/'
os.chdir(data_dir)

# %%
all_files = os.listdir()
file_names = [file for file in all_files if file[-4::] == '.txt']
print(file_names)
# Out:
# ['sci.crypt.txt', 'comp.sys.mac.hardware.txt', 'misc.forsale.txt', 'soc.religion.christian.txt', 'rec.sport.baseball.txt', 'rec.sport.hockey.txt', 'comp.sys.ibm.pc.hardware.txt', 'talk.politics.guns.txt', 'rec.autos.txt', 'alt.atheism.txt', 'comp.os.ms-windows.misc.txt', 'sci.electronics.txt', 'comp.windows.x.txt', 'talk.religion.misc.txt', 'talk.politics.mideast.txt', 'sci.med.txt', 'rec.motorcycles.txt', 'comp.graphics.txt', 'sci.space.txt', 'talk.politics.misc.txt']

# %% [markdown]
# ### See What Information We Can Get From the "list" CSV File

# %%
master_df = pd.read_csv('talk.religion.misc.list.csv')
master_df.head(10)
# Out:
#             newsgroup  document_id
# 0  talk.religion.misc        82757
# 1  talk.religion.misc        82758
# 2  talk.religion.misc        82759
# 3  talk.religion.misc        82760
# 4  talk.religion.misc        82763
# 5  talk.religion.misc        82766
# 6  talk.religion.misc        82767
# 7  talk.religion.misc        82771
# 8  talk.religion.misc        82772
# 9  talk.religion.misc        82774

# %%
grouped_by_group_df = master_df.groupby(by = "newsgroup")
grouped_by_group_df.count()
# Out:
#                     document_id
# newsgroup
# talk.religion.misc          628

# %% [markdown]
# Evidently, for whatever reason, this CSV file only contains entries for the `talk.religion.misc` category. Thus, if we want a similar master document for all of the categories, we're going to have to create it ourselves...this should NOT be hard to do once we figure out a good way to parse through the txt files. **Thus**, we have re-named the file to `talk.religion.misc.list.csv`

# %%
grouped_by_id_df = master_df.groupby(by = 'document_id')
print(grouped_by_id_df.count().max() == grouped_by_id_df.count().min(), end = '\n\n\n')
print(grouped_by_id_df.count().min() == grouped_by_id_df.count().mean(), end = '\n\n\n')
print(grouped_by_id_df.count().max() == grouped_by_id_df.count().mean())
# Out:
# newsgroup    True
# dtype: bool
#
#
# newsgroup    True
# dtype: bool
#
#
# newsgroup    True
# dtype: bool

# %% [markdown]
# We can tell that each row in this df is **unique** as should be the case.

# %% [markdown]
# ### Write A Function That Opens and Parses Each Txt File

# %%
def txt_to_df(file_name: str, *args, **kwargs):
    """
    Purpose
    -------
    The purpose of this function is to take the content that exists in one of the .txt files given
    by the data dump on Kaggle (see link above) and parse it so that the result is a DataFrame whose
    rows correspond to each document that is referenced in the file. This is not an immediately 
    straight-forward task due to the fact that each file is simply a blob of text. For that reason,
    the parsing is done using regular expressions that take advantage of the minimal structure that
    is present. What exactly is taken advantage of is spelled out in the comments of this function's
    source code.
    
    Parameters
    ----------
    file_name - (str) This string represents the file name that contains information about the 
                      hierachical class that you are interested in wrangling. You may include a path
                      to the file if this notebook is not in the directory in which it is stored on 
                      your machine.
    
    Returns
    -------
    to_return - (Pandas DataFrame) this table has columns ["News_Group", "document_id", "From",
                                   "Subject", "raw_text"] and each of its rows corresponds to different
                                   documents referenced in the .txt file.
    
    References
    ----------
    1. https://medium.com/factory-mind/regex-tutorial-a-simple-cheatsheet-by-examples-649dc1c3f285
    2. https://stackoverflow.com/questions/6109882/regex-match-all-characters-between-two-strings
    3. https://docs.python.org/3/library/re.html
    """
    ### first we have to open up the file and save it to a string
    my_file = open(file_name, 'rb')
        # reading the file as bytes seemed to be the only way to get this to work
    file_str = str(my_file.read())
        # reading the files as bytes means that we have to manually make it into a string
    my_file.close()
        # always have to close any file that you open.
    assert( type(file_str) == str )
        # you can never be too sure.
    
    ### Now parse the file
    # First, begin by spliting the string based off of the occurances of "Newsgroup: file (without 
    # .txt extension)" since that seperates each of the different documents present in this massive file.
    # Another reason why this is a nice string to split in is that each reference to a new document has
    # the exact same news group line.
    newsgroup_name = re.sub(pattern = r".txt",
                            repl = "",
                            string = file_name)
        # just have to remove the file extension from the file name that the user has specified.
    documents_list = re.split(pattern = "Newsgroup: {}".format(newsgroup_name),
                              string = file_str)
    
    # For each document, extact all of the desired information
    extracted_info_dict = {}
    to_dock_index = 0
        # see below for what this is used for.
    for doc_index, doc_str in enumerate(documents_list):
        if len(doc_str) < 10:
            # first, check to see if it's a legit document. Cases in which it won't be are ones such 
            # as whenthe string technically starts with "b" that is then followed by "\\nNewsgroup: " 
            # meaning that spliting on the news group string will mean that the first string in the 
            # resulting list will simply be something like "b\\n" which is not at all useful. The threshold 
            # of 10 can be changed if one that performs better is determined.
            to_dock_index += 1
        else:
            doc_index -= to_dock_index
                # simply to reset the indices to make sure everything is consistent.
            # then, do your searches
            doc_id_match = re.search(r"(?<=document_id: )[0-9]+(?=\\n)",
                                     doc_str,
                                     re.IGNORECASE)
                # NOTE that this is a Match object.
            
                # the ?<= part is a look-behind meaning that the search will only return results that are
                # a series of numbers preceded by the string specified in the look-behind. Another nice 
                # thing about this is that the part that is in the look-behind will NOT get returned.
                # The ?= is a look-ahead that operates in the exact same way. The `re.IGNORECASE` is used
                # because although each new instance of a document includes an assignment of a document ID,
                # the casing to do so varies.
            doc_from_match = re.search(r"(?<=From: ).*?(?=\\n)",
                                       doc_str,
                                       re.IGNORECASE)
                # the `.*?` signifies a "lazy" search which means that search will return whatever it 
                # finds first as opposed to `.*` which would return the last instance it finds of what 
                # the search specifies which is not useful here because that would be the next document!
            doc_subject_match = re.search(r"(?<=Subject: ).*?(?=\\n)",
                                          doc_str,
                                          re.IGNORECASE)
            try:
                # the reason for the try and except block is that if any of the searchs comes up empty, then
                # the use of the `.end()` method will simply raise an exception that will interupt the entire
                # function.
                index_to_start_text = max([ doc_id_match.end(), 
                                            doc_from_match.end(),
                                            doc_subject_match.end() ])
                    # the `.end()` method returns an integer that represents the index of the last character
                    # of the string that it found in the search. The reason why we want the max final index
                    # of all of these searches is that it represents our best guess as to when the text starts.
            except:
                index_to_start_text = 0
            extracted_info_dict[doc_index] = {"News_Group" : newsgroup_name,
                                              "document_id" : int(doc_id_match.group(0)) if doc_id_match else None,
                                              "From" : doc_from_match.group(0) if doc_from_match else None,
                                              "Subject" : doc_subject_match.group(0) if doc_subject_match else None,
                                              "raw_text" : doc_str[index_to_start_text::]}
    
    ### Wrangle All of The Extracted Information Into a DataFrame
    extracted_info_df = pd.DataFrame(extracted_info_dict).T
    to_return = extracted_info_df
    
    return to_return

# %% [markdown]
# ### Run it on Each File

# %%
parsed_dfs_list = [ txt_to_df(file) for file in file_names ]
assert( len(parsed_dfs_list) == 20 )

# %%
parsed_dfs_list[np.random.randint(0, 20)].head(20)
# Out:
#          News_Group document_id  \
# 0   rec.motorcycles      101725
# 1   rec.motorcycles      102616
# 2   rec.motorcycles      103117
# 3   rec.motorcycles      103118
# 4   rec.motorcycles      103119
# 5   rec.motorcycles      103120
# 6   rec.motorcycles      103121
# 7   rec.motorcycles      103122
# 8   rec.motorcycles      103123
# 9   rec.motorcycles      103124
# 10  rec.motorcycles      103125
# 11  rec.motorcycles      103126
# 12  rec.motorcycles      103127
# 13  rec.motorcycles      103128
# 14  rec.motorcycles      103129
# 15  rec.motorcycles      103130
# 16  rec.motorcycles      103131
# 17  rec.motorcycles      103132
# 18  rec.motorcycles      103133
# 19  rec.motorcycles      103134
#
#                                                 From  \
# 0                  jeff@mri.com (Jonathan Jefferies)
# 1   blgardne@javelin.sim.es.com (Dances With Bikers)
# 2             manes@magpie.linknet.com (Steve Manes)
# 3                    randy@megatek.com (Randy Davis)
# 4      Stafford@Vax2.Winona.MSUS.Edu (John Stafford)
# 5                    maven@eskimo.com (Norman Hamer)
# 6     MJMUISE@1302.watstar.uwaterloo.ca (Mike Muise)
# 7    egreen@East.Sun.COM (Ed Green - Pixel Cruncher)
# 8    egreen@East.Sun.COM (Ed Green - Pixel Cruncher)
# 9         jrwaters@eos.ncsu.edu (JACK ROGERS WATERS)
# 10     ai598@cleveland.Freenet.Edu (Mike Sturdevant)
# 11                          bclarke@galaxy.gov.bc.ca
# 12     ai598@cleveland.Freenet.Edu (Mike Sturdevant)
# 13               cjackson@adobe.com (Curtis Jackson)
# 14                    azw@aber.ac.uk (Andy Woodward)
# 15                    azw@aber.ac.uk (Andy Woodward)
# 16                    azw@aber.ac.uk (Andy Woodward)
# 17                    azw@aber.ac.uk (Andy Woodward)
# 18                    azw@aber.ac.uk (Andy Woodward)
# 19                    azw@aber.ac.uk (Andy Woodward)
#
#                                               Subject  \
# 0                                   Re: Lexan Polish?
# 1                              FAQ - What is the DoD?
# 2                                    Re: Oops! Oh no!
# 3                         Re: A Miracle in California
# 4                          Re: more DoD paraphernalia
# 5                         Re: A Miracle in California
# 6                             Re: Drinking and Riding
# 7                                  Re: insect impacts
# 8                         Re: A Miracle in California
# 9                              Re: Cultural Enquiries
# 10                  Carrying crutches (was Re: Living
# 11       Re: Kawi Zephyr? (was Re: Vision vs GpZ 550)
# 12                    Re: Ed must be a Daemon Child!!
# 13                      Re: Identify this bike for me
# 14                             Re: Cultural Enquiries
# 15                re: Countersteering_FAQ please post
# 16                                    Re: Dr. Demento
# 17  Re: pink tools [was: Re: What is it with girlf...
# 18                             Re: Cultural Enquiries
# 19                            Re: Drinking and Riding
#
#                                              raw_text
# 0   \n\nIn article <C41soE.M62@ns1.nodak.edu> wilk...
# 1   \n\nThis is a periodic posting intended to ans...
# 2   \n\nWm. L. Ranck (ranck@joesbar.cc.vt.edu) wro...
# 3   \n\nIn article <1ppvof$92a@seven-up.East.Sun.C...
# 4   \n\nIn article <1pppnrINNitg@cronkite.Central....
# 5   \n\nRe: Waving...\n\nI must say, that the cour...
# 6   \n\nIn article <C4wKBp.B9w@eskimo.com>, maven@...
# 7   \n\nIn article 7290@rd.hydro.on.ca, jlevine@rd...
# 8   \n\nIn article 602CV3dTx01@JUTS.ccc.amdahl.com...
# 9   \n\nIn article <C50uGG.9As@cmptrc.lonestar.org...
# 10  \n\n\nIn a previous article, pooder@rchland.vn...
# 11  \n\nIn article <1993Apr4.135829.28141@pro-have...
# 12  \n\n\nIn a previous article, svoboda@rtsg.mot....
# 13  \n\nIn article <1993Apr5.193804.18482@ucsu.Col...
# 14  \n\n\nIn article <Stafford-310393095530@staffo...
# 15  \n\n\nIn article <C4zKCL.FGC@ux1.cso.uiuc.edu>...
# 16  \n\n\nIn article <1993Mar31.194202.7809@cs.bro...
# 17  \n\nI ONLY Just prevented myself from diving  ...
# 18  \n\n\nIn article <1pcl6i$e4i@bigboote.WPI.EDU>...
# 19  \n\n\nIn article <1993Apr3.200529.2206@galaxy....

# %% [markdown]
# ### Put the Returned DataFrames Together

# %%
total_df_0 = pd.concat(parsed_dfs_list).reset_index(drop = True)
assert( total_df_0.shape[0] == sum( [df.shape[0] for df in parsed_dfs_list] ) )
total_df_0.tail(20)
# Out:
#                News_Group document_id  \
# 37642  talk.politics.misc      179093
# 37643  talk.politics.misc      179094
# 37644  talk.politics.misc      179095
# 37645  talk.politics.misc      179097
# 37646  talk.politics.misc      179098
# 37647  talk.politics.misc      179099
# 37648  talk.politics.misc      179102
# 37649  talk.politics.misc      179103
# 37650  talk.politics.misc      179105
# 37651  talk.politics.misc      179106
# 37652  talk.politics.misc      179107
# 37653  talk.politics.misc      179108
# 37654  talk.politics.misc      179109
# 37655  talk.politics.misc      179110
# 37656  talk.politics.misc      179111
# 37657  talk.politics.misc      179112
# 37658  talk.politics.misc      179113
# 37659  talk.politics.misc      179114
# 37660  talk.politics.misc      179115
# 37661  talk.politics.misc      179116
#
#                                                  From  \
# 37642        mst4298@rigel.tamu.edu (Mitchell S Todd)
# 37643          demon@desire.wright.edu (Not a Boomer)
# 37644           V2110A@VM.TEMPLE.EDU (Richard Hoenes)
# 37645  ck347@cleveland.Freenet.Edu (Richard A. Mulac)
# 37646               asper@calvin.uucp (Alan E. Asper)
# 37647            goykhman@apollo.hp.com (Red Herring)
# 37648     hallam@dscomsa.desy.de (Phill Hallam-Baker)
# 37649              thyat@sdf.lonestar.org (Tom Hyatt)
# 37650                visser@convex.com (Lance Visser)
# 37651            cramer@optilink.COM (Clayton Cramer)
# 37652            cramer@optilink.COM (Clayton Cramer)
# 37653                 walsh@optilink.COM (Mark Walsh)
# 37654            cramer@optilink.COM (Clayton Cramer)
# 37655            cramer@optilink.COM (Clayton Cramer)
# 37656            cramer@optilink.COM (Clayton Cramer)
# 37657            cramer@optilink.COM (Clayton Cramer)
# 37658            cramer@optilink.COM (Clayton Cramer)
# 37659            cramer@optilink.COM (Clayton Cramer)
# 37660           V2110A@VM.TEMPLE.EDU (Richard Hoenes)
# 37661           V2110A@VM.TEMPLE.EDU (Richard Hoenes)
#
#                                           Subject  \
# 37642                            Re: Waco Burnout
# 37643        Re: Not talking to soldiers, part II
# 37644                                        Waco
# 37645                            Re: Waco Burnout
# 37646     Re: Janet Reno killed the Waco children
# 37647     Re: Janet Reno killed the Waco children
# 37648                            Re: WACO burning
# 37649            Re: Waco survivors 1715 19 April
# 37650             Re: Waco Investigation Paranoia
# 37651                     The Government Is LYING
# 37652         Re: New Study Out On Gay Percentage
# 37653                  Re: Freedom of Association
# 37654         Re: New Study Out On Gay Percentage
# 37655         Re: New Study Out On Gay Percentage
# 37656         Re: New Study Out On Gay Percentage
# 37657  Re: WACO: Clinton press conference, part 1
# 37658         Re: New Study Out On Gay Percentage
# 37659         Re: New Study Out On Gay Percentage
# 37660                  Why didn\'t they come out?
# 37661     Re: Janet Reno killed the Waco children
#
#                                                 raw_text
# 37642  \n\nrja@mahogany126.cray.com (Russ Anderson) w...
# 37643  \n\nIn article <C5trFx.B38@csulb.edu>, sicherm...
# 37644  \n\nDo all those who are saying the government...
# 37645  \n\n\nDoesn\'t seem like those responsible for...
# 37646  \n\nIn article <1r1pn6$nap@lll-winken.llnl.gov...
# 37647  \n\nIn article <fern.735342004@camelot> fern@c...
# 37648  \n\n\nIn article <1r7bh0$cc2@nwfocus.wa.com>, ...
# 37649  \n\nIn article <1993Apr20.135819.14473@e2big.m...
# 37650  \n\nIn <16BB98B5A.V2110A@VM.TEMPLE.EDU> V2110A...
# 37651  \n\n\nYesterday, the FBI was saying that at le...
# 37652  \n\nIn article <1993Apr22.163758.17886@galileo...
# 37653  \n\nFrom article <pdb059-220493112512@kilimanj...
# 37654  \n\nIn article <C5w5CB.Ct4@rahul.net>, starowl...
# 37655  \n\nIn article <C5wA0D.IvA@murdoch.acc.Virgini...
# 37656  \n\nIn article <1993Apr22.142032.26340@cs.nott...
# 37657  \n\nIn article <93Apr22.234553edt.47633@neat.c...
# 37658  \n\nIn article <1993Apr22.165002.18208@galileo...
# 37659  \n\nIn article <1993Apr22.165729.18393@galileo...
# 37660  \n\nAfter the initial gun battle was over, the...
# 37661  \n\nIn article <1993Apr20.153450.27407@ncsu.ed...

# %% [markdown]
# ### Check For Duplicates

# %%
total_df_0.document_id.value_counts()
# Out:
# 54185     8
# 54180     8
# 54250     8
# 54251     8
# 54253     8
#          ..
# 51818     2
# 51817     2
# 51816     2
# 51815     2
# 124146    2
# Name: document_id, Length: 15404, dtype: int64

# %%
total_df_0.groupby(by = "document_id").get_group(54185)
    # Note that the 54185 ID was used because it was one of the IDs that occured 
    # 8 (!!) times.
# Out:
#                News_Group document_id  \
# 10594    rec.sport.hockey       54185
# 11593    rec.sport.hockey       54185
# 13930  talk.politics.guns       54185
# 14840  talk.politics.guns       54185
# 18321         alt.atheism       54185
# 19120         alt.atheism       54185
# 21946     sci.electronics       54185
# 22929     sci.electronics       54185
#
#                                                  From  \
# 10594        gld@cunixb.cc.columbia.edu (Gary L Dare)
# 11593        gld@cunixb.cc.columbia.edu (Gary L Dare)
# 13930          lvc@cbnews.cb.att.com (Larry Cipriani)
# 14840          lvc@cbnews.cb.att.com (Larry Cipriani)
# 18321                    mathew <mathew@mantis.co.uk>
# 19120                    mathew <mathew@mantis.co.uk>
# 21946  gsulliva@enuxha.eas.asu.edu (Glenn A Sullivan)
# 22929  gsulliva@enuxha.eas.asu.edu (Glenn A Sullivan)
#
#                                      Subject  \
# 10594          Re: TV Schedule for Next Week
# 11593          Re: TV Schedule for Next Week
# 13930              Re: My Gun is like my....
# 14840              Re: My Gun is like my....
# 18321               Re: Cults Vs. Religions?
# 19120               Re: Cults Vs. Religions?
# 21946  Re: How do you build neural networks?
# 22929  Re: How do you build neural networks?
#
#                                                 raw_text
# 10594  \n\njpc@philabs.philips.com (John P. Curcio) w...
# 11593  \n\njpc@philabs.philips.com (John P. Curcio) w...
# 13930  \n\nIn article <1993Apr16.194708.13273@vax.oxf...
# 14840  \n\nIn article <1993Apr16.194708.13273@vax.oxf...
# 18321  \n\nmangoe@cs.umd.edu (Charley Wingate) writes...
# 19120  \n\nmangoe@cs.umd.edu (Charley Wingate) writes...
# 21946  \n\nmmoss@ic.sunysb.edu (Matthew D Moss) write...
# 22929  \n\nmmoss@ic.sunysb.edu (Matthew D Moss) write...

# %% [markdown]
# **Evidently**, we have instances in which there are **duplicates** between the new group where the rows are exactly the same **as well as** when the **same document ID** is used accross the different News Groups. To remedy this, we will:
# 1. First, drop all of the duplicates which will address the issue of when the exact same row appears more than once.
# 2. Drop the `document_id` column since it is not its entries are NOT useful unique IDs since a give ID is used multiple times across the different News Groups.
# 3. Reset the index while setting the `drop` argument of that method to `True` so as to not have that `index` column in the result.
# 4. Lastly, perform adjusted-steps of above to ensure these changes had the desired effect.

# %%
total_df_1 = total_df_0.drop_duplicates(subset = "Subject").reset_index(drop = True).drop(columns = "document_id")
    # the "Subject" column was the column that made the most sense to check for Duplicates since one could be the
    # author of multiple documents, making the `From` column useless, and there can be so many nuanced differences
    # between otherwise identical texts in the `raw_text` column.
total_df_1
# Out:
#                News_Group                                         From  \
# 0               sci.crypt  Marc VanHeyningen <mvanheyn@cs.indiana.edu>
# 1               sci.crypt  mvanheyn@cs.indiana.edu (Marc VanHeyningen)
# 2               sci.crypt                         Jim-Miller@suite.com
# 3               sci.crypt   C445585@mizzou1.missouri.edu (John Kelsey)
# 4               sci.crypt               grady@netcom.com (1016/2EF221)
# ...                   ...                                          ...
# 10382  talk.politics.misc  garrod@dynamo.ecn.purdue.edu (David Garrod)
# 10383  talk.politics.misc           pyotr@halcyon.com (Peter D. Hampe)
# 10384  talk.politics.misc  Clinton-HQ@Campaign92.Org (The White House)
# 10385  talk.politics.misc         cramer@optilink.COM (Clayton Cramer)
# 10386  talk.politics.misc        V2110A@VM.TEMPLE.EDU (Richard Hoenes)
#
#                                                  Subject  \
# 0                       RIPEM Frequently Asked Questions
# 1                 RIPEM Frequently Noted Vulnerabilities
# 2                Certifying Authority question answered.
# 3                            "Rubber-hose cryptanalysis"
# 4                                    Declassifying media
# ...                                                  ...
# 10382                                       WACO burning
# 10383  Phill says Koresh == Hitler, was Welcome to Po...
# 10384   CLINTON: Fact Sheet on Russian Statement 4.23.93
# 10385                            The Government Is LYING
# 10386                         Why didn\'t they come out?
#
#                                                 raw_text
# 0      \n\nArchive-name: ripem/faq\nLast-update: Sun,...
# 1      \n\nArchive-name: ripem/attacks\nLast-update: ...
# 2      \n\n>>If you have access to FTP, try FTPing to...
# 3      \n\n   Some sick part of me really liked that ...
# 4      \n\nThere are many Urban Legends (maybe this o...
# ...                                                  ...
# 10382  \n\n\n\nIt is interesting, sometimes, to liste...
# 10383  \n\nhallam@dscomsa.desy.de (Phill Hallam-Baker...
# 10384  \n\n\n\n\n                         The White H...
# 10385  \n\n\nYesterday, the FBI was saying that at le...
# 10386  \n\nAfter the initial gun battle was over, the...
#
# [10387 rows x 4 columns]

# %%
total_df_1.groupby(by = "Subject").count().describe()
# Out:
#        News_Group     From  raw_text
# count     10387.0  10387.0   10387.0
# mean          1.0      1.0       1.0
# std           0.0      0.0       0.0
# min           1.0      1.0       1.0
# 25%           1.0      1.0       1.0
# 50%           1.0      1.0       1.0
# 75%           1.0      1.0       1.0
# max           1.0      1.0       1.0

# %% [markdown]
# We can now confidently conclude that each row in this DataFrame is in fact **unique**. The result is 10387 documents to work with.

# %% [markdown]
# ### Now Check For Null Values

# %%
total_df_1.isnull().sum()
# Out:
# News_Group    0
# From          0
# Subject       0
# raw_text      0
# dtype: int64

# %% [markdown]
# **Nothing** to worry about here. Cool!

# %% [markdown]
# # Re-structure The Storage of The News Groups in a More Hierarchical Way

# %%
total_df_1[ ["Tier_{}".format(i) for i in range(1, 6, 1)] ] = total_df_1.News_Group.str.split(pat = '.', expand = True)
total_df_1
# Out:
#                News_Group                                         From  \
# 0               sci.crypt  Marc VanHeyningen <mvanheyn@cs.indiana.edu>
# 1               sci.crypt  mvanheyn@cs.indiana.edu (Marc VanHeyningen)
# 2               sci.crypt                         Jim-Miller@suite.com
# 3               sci.crypt   C445585@mizzou1.missouri.edu (John Kelsey)
# 4               sci.crypt               grady@netcom.com (1016/2EF221)
# ...                   ...                                          ...
# 10382  talk.politics.misc  garrod@dynamo.ecn.purdue.edu (David Garrod)
# 10383  talk.politics.misc           pyotr@halcyon.com (Peter D. Hampe)
# 10384  talk.politics.misc  Clinton-HQ@Campaign92.Org (The White House)
# 10385  talk.politics.misc         cramer@optilink.COM (Clayton Cramer)
# 10386  talk.politics.misc        V2110A@VM.TEMPLE.EDU (Richard Hoenes)
#
#                                                  Subject  \
# 0                       RIPEM Frequently Asked Questions
# 1                 RIPEM Frequently Noted Vulnerabilities
# 2                Certifying Authority question answered.
# 3                            "Rubber-hose cryptanalysis"
# 4                                    Declassifying media
# ...                                                  ...
# 10382                                       WACO burning
# 10383  Phill says Koresh == Hitler, was Welcome to Po...
# 10384   CLINTON: Fact Sheet on Russian Statement 4.23.93
# 10385                            The Government Is LYING
# 10386                         Why didn\'t they come out?
#
#                                                 raw_text Tier_1    Tier_2  \
# 0      \n\nArchive-name: ripem/faq\nLast-update: Sun,...    sci     crypt
# 1      \n\nArchive-name: ripem/attacks\nLast-update: ...    sci     crypt
# 2      \n\n>>If you have access to FTP, try FTPing to...    sci     crypt
# 3      \n\n   Some sick part of me really liked that ...    sci     crypt
# 4      \n\nThere are many Urban Legends (maybe this o...    sci     crypt
# ...                                                  ...    ...       ...
# 10382  \n\n\n\nIt is interesting, sometimes, to liste...   talk  politics
# 10383  \n\nhallam@dscomsa.desy.de (Phill Hallam-Baker...   talk  politics
# 10384  \n\n\n\n\n                         The White H...   talk  politics
# 10385  \n\n\nYesterday, the FBI was saying that at le...   talk  politics
# 10386  \n\nAfter the initial gun battle was over, the...   talk  politics
#
#       Tier_3 Tier_4 Tier_5
# 0       None   None   None
# 1       None   None   None
# 2       None   None   None
# 3       None   None   None
# 4       None   None   None
# ...      ...    ...    ...
# 10382   misc   None   None
# 10383   misc   None   None
# 10384   misc   None   None
# 10385   misc   None   None
# 10386   misc   None   None
#
# [10387 rows x 9 columns]

# %%
total_df_2 = total_df_1.drop(columns = "News_Group")
total_df_2.head(15)
# Out:
#                                                  From  \
# 0         Marc VanHeyningen <mvanheyn@cs.indiana.edu>
# 1         mvanheyn@cs.indiana.edu (Marc VanHeyningen)
# 2                                Jim-Miller@suite.com
# 3          C445585@mizzou1.missouri.edu (John Kelsey)
# 4                      grady@netcom.com (1016/2EF221)
# 5                       gtoal@gtoal.com (Graham Toal)
# 6                      warlord@MIT.EDU (Derek Atkins)
# 7   neuhaus@bloch.informatik.uni-kl.de (Stephan Ne...
# 8                        WHMurray@DOCKMASTER.NCSC.MIL
# 9                   ho@cs.arizona.edu (Hilarie Orman)
# 10                        ken@sugra.uucp (Kenneth Ng)
# 11        ninassup@athena.mit.edu (Nikos I Nassuphis)
# 12                kubo@zariski.harvard.edu (Tal Kubo)
# 13  bontchev@fbihh.informatik.uni-hamburg.de (Vess...
# 14                       WHMurray@DOCKMASTER.NCSC.MIL
#
#                                         Subject  \
# 0              RIPEM Frequently Asked Questions
# 1        RIPEM Frequently Noted Vulnerabilities
# 2       Certifying Authority question answered.
# 3                   "Rubber-hose cryptanalysis"
# 4                           Declassifying media
# 5       Re: Hard drive security for FBI targets
# 6                      Re: disk safety measure?
# 7                 Re: PGP 2.2: general comments
# 8                                Licensing.....
# 9   Re: Licensing of public key implementations
# 10             Re: Identifying / Securing Files
# 11                            LGA ncrypt source
# 12  Re: Illegal Wiretaps (was Denning\'s Trust)
# 13                     Re: opinions of RC2 alg.
# 14                                 Licensing...
#
#                                              raw_text Tier_1 Tier_2 Tier_3  \
# 0   \n\nArchive-name: ripem/faq\nLast-update: Sun,...    sci  crypt   None
# 1   \n\nArchive-name: ripem/attacks\nLast-update: ...    sci  crypt   None
# 2   \n\n>>If you have access to FTP, try FTPing to...    sci  crypt   None
# 3   \n\n   Some sick part of me really liked that ...    sci  crypt   None
# 4   \n\nThere are many Urban Legends (maybe this o...    sci  crypt   None
# 5   \n\n\tFrom: res@colnet.cmhnet.org (Rob Stampfl...    sci  crypt   None
# 6   \n\n-----BEGIN PGP SIGNED MESSAGE-----\n\nIn a...    sci  crypt   None
# 7   \n\nneuhaus@vier.informatik.uni-kl.de (Stephan...    sci  crypt   None
# 8   \n\n\n>This thread brings up the more general ...    sci  crypt   None
# 9   \n\nWith regard to your speculations on NSA in...    sci  crypt   None
# 10  \n\nIn article <2bb29f4c@mash.boulder.co.us: r...    sci  crypt   None
# 11  \n\nI got a number of requests for code.\nSo, ...    sci  crypt   None
# 12  \n\nIn article <1ppg02$i2k@bigboote.WPI.EDU> \...    sci  crypt   None
# 13  \n\nMarkowitz@DOCKMASTER.NCSC.MIL writes:\n\n>...    sci  crypt   None
# 14  \n\n\n>This actually supports Bill\'s speculat...    sci  crypt   None
#
#    Tier_4 Tier_5
# 0    None   None
# 1    None   None
# 2    None   None
# 3    None   None
# 4    None   None
# 5    None   None
# 6    None   None
# 7    None   None
# 8    None   None
# 9    None   None
# 10   None   None
# 11   None   None
# 12   None   None
# 13   None   None
# 14   None   None

# %% [markdown]
# # Clean the Text Data That We Have Extracted

# %%
# let's get an example text so that we can figure out what we need to clean up.
example_text = total_df_2.raw_text[69]

# %%
example_text[:3000:]
# Out:
# "\\n\\nArchive-name: cryptography-faq/part02\\nLast-modified: 1993/4/15\\n\\n\\nFAQ for sci.crypt, part 2: Net Etiquette\\n\\nThis is the second of ten parts of the sci.crypt FAQ. The parts are\\nmostly independent, but you should read the first part before the rest.\\nWe don\\'t have the time to send out missing parts by mail, so don\\'t ask.\\nNotes such as ``[KAH67]\\'\\' refer to the reference list in the last part.\\n\\nThe sections of this FAQ are available via anonymous FTP to rtfm.mit.edu \\nas /pub/usenet/news.answers/cryptography-faq/part[xx].  The Cryptography \\nFAQ is posted to the newsgroups sci.crypt, sci.answers, and news.answers \\nevery 21 days.\\n\\n\\nContents:\\n\\n* What groups are around? What\\'s a FAQ? Who am I? Why am I here?\\n* Do political discussions belong in sci.crypt?\\n* How do I present a new encryption scheme in sci.crypt?\\n\\n\\n* What groups are around? What\\'s a FAQ? Who am I? Why am I here?\\n\\n  Read news.announce.newusers and news.answers for a few weeks. Always\\n  make sure to read a newsgroup for some time before you post to it.\\n  You\\'ll be amazed how often the same question can be asked in the same\\n  newsgroup. After a month you\\'ll have a much better sense of what the\\n  readers want to see.\\n\\n* Do political discussions belong in sci.crypt?\\n\\n  No. In fact some newsgroups (notably misc.legal.computing) were\\n  created exactly so that political questions like ``Should RSA be\\n  patented?\\'\\' don\\'t get in the way of technical discussions. Many\\n  sci.crypt readers also read misc.legal.computing, comp.org.eff.talk,\\n  comp.patents, sci.math, comp.compression, et al.; for the benefit of\\n  people who don\\'t care about those other topics, try to put your\\n  postings in the right group.\\n\\n  Questions about microfilm and smuggling and other non-cryptographic\\n  ``spy stuff\\'\\' don\\'t belong in sci.crypt either.\\n\\n* How do I present a new encryption scheme in sci.crypt?\\n\\n  ``I just came up with this neat method of encryption. Here\\'s some\\n  ciphertext: FHDSIJOYW^&%$*#@OGBUJHKFSYUIRE. Is it strong?\\'\\' Without a\\n  doubt questions like this are the most annoying traffic on sci.crypt.\\n\\n  If you have come up with an encryption scheme, providing some\\n  ciphertext from it is not adequate. Nobody has ever been impressed by\\n  random gibberish. Any new algorithm should be secure even if the\\n  opponent knows the full algorithm (including how any message key is\\n  distributed) and only the private key is kept secret. There are some\\n  systematic and unsystematic ways to take reasonably long ciphertexts\\n  and decrypt them even without prior knowledge of the algorithm, but\\n  this is a time-consuming and possibly fruitless exercise which most\\n  sci.crypt readers won\\'t bother with.\\n\\n  So what do you do if you have a new encryption scheme? First of all,\\n  find out if it\\'s really new. Look through this FAQ for references and\\n  related methods. Familiarize yourself with the literature and the\\n  introductory textbooks.\\n\\n  When you"

# %% [markdown]
# ### Write a Function To Do This

# %%
def my_str_cleaner(row, *args, **kwargs):
    """
    Purpose
    -------
    
    Parameters
    ----------
    
    Returns
    -------
    
    References
    ----------
    1.
    """
    ###
    white_space_normalizer = lambda x: x if x[0] != ' ' else x[re.match(r" +", x).end()::]
    raw_str = row["raw_text"]
    
    split_on_new_lines_list = raw_str.split("\\n")
    almost_str = " ".join([ white_space_normalizer(text) for text in split_on_new_lines_list if len(text) and text[0:3] != '---' ])
    
    split_on_white_space_list = almost_str.split()
    final_str = " ".join([ text for text in split_on_white_space_list ])
    
    to_return = final_str
    return to_return

# %%
total_df_2["cleaned_text"] = total_df_2.apply(my_str_cleaner, axis = 1)

# %%
total_df_2
# Out:
#                                               From  \
# 0      Marc VanHeyningen <mvanheyn@cs.indiana.edu>
# 1      mvanheyn@cs.indiana.edu (Marc VanHeyningen)
# 2                             Jim-Miller@suite.com
# 3       C445585@mizzou1.missouri.edu (John Kelsey)
# 4                   grady@netcom.com (1016/2EF221)
# ...                                            ...
# 10382  garrod@dynamo.ecn.purdue.edu (David Garrod)
# 10383           pyotr@halcyon.com (Peter D. Hampe)
# 10384  Clinton-HQ@Campaign92.Org (The White House)
# 10385         cramer@optilink.COM (Clayton Cramer)
# 10386        V2110A@VM.TEMPLE.EDU (Richard Hoenes)
#
#                                                  Subject  \
# 0                       RIPEM Frequently Asked Questions
# 1                 RIPEM Frequently Noted Vulnerabilities
# 2                Certifying Authority question answered.
# 3                            "Rubber-hose cryptanalysis"
# 4                                    Declassifying media
# ...                                                  ...
# 10382                                       WACO burning
# 10383  Phill says Koresh == Hitler, was Welcome to Po...
# 10384   CLINTON: Fact Sheet on Russian Statement 4.23.93
# 10385                            The Government Is LYING
# 10386                         Why didn\'t they come out?
#
#                                                 raw_text Tier_1    Tier_2  \
# 0      \n\nArchive-name: ripem/faq\nLast-update: Sun,...    sci     crypt
# 1      \n\nArchive-name: ripem/attacks\nLast-update: ...    sci     crypt
# 2      \n\n>>If you have access to FTP, try FTPing to...    sci     crypt
# 3      \n\n   Some sick part of me really liked that ...    sci     crypt
# 4      \n\nThere are many Urban Legends (maybe this o...    sci     crypt
# ...                                                  ...    ...       ...
# 10382  \n\n\n\nIt is interesting, sometimes, to liste...   talk  politics
# 10383  \n\nhallam@dscomsa.desy.de (Phill Hallam-Baker...   talk  politics
# 10384  \n\n\n\n\n                         The White H...   talk  politics
# 10385  \n\n\nYesterday, the FBI was saying that at le...   talk  politics
# 10386  \n\nAfter the initial gun battle was over, the...   talk  politics
#
#       Tier_3 Tier_4 Tier_5                                       cleaned_text
# 0       None   None   None  Archive-name: ripem/faq Last-update: Sun, 7 Ma...
# 1       None   None   None  Archive-name: ripem/attacks Last-update: 31 Ma...
# 2       None   None   None  >>If you have access to FTP, try FTPing to rsa...
# 3       None   None   None  Some sick part of me really liked that phrase....
# 4       None   None   None  There are many Urban Legends (maybe this ought...
# ...      ...    ...    ...                                                ...
# 10382   misc   None   None  It is interesting, sometimes, to listen to U.S...
# 10383   misc   None   None  hallam@dscomsa.desy.de (Phill Hallam-Baker) wr...
# 10384   misc   None   None  The White House Office of the Press Secretary ...
# 10385   misc   None   None  Yesterday, the FBI was saying that at least th...
# 10386   misc   None   None  After the initial gun battle was over, they ha...
#
# [10387 rows x 9 columns]
